# %%
import os

# %%
# %pwd
# Out:
# 'd:\\Gen_AI_Projects\\PROJECTS\\DL-Chicken-Disease-Classification\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\Gen_AI_Projects\\PROJECTS\\DL-Chicken-Disease-Classification'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
from cnnClassification.constants import *
from cnnClassification.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir 
        )

        return data_ingestion_config

# %%
import os
import urllib.request as request
import zipfile
from cnnClassification import logger
from cnnClassification.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config


    
    def download_file(self):
        if not os.path.exists(self.config.local_data_file):
            filename, headers = request.urlretrieve(
                url = self.config.source_URL,
                filename = self.config.local_data_file
            )
            logger.info(f"{filename} download! with following info: \n{headers}")
        else:
            logger.info(f"File already exists of size: {get_size(Path(self.config.local_data_file))}")  


    
    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file into the data directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# [2026-07-29 01:30:50,744: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-07-29 01:30:50,750: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-07-29 01:30:50,754: INFO: common: created directory at: artifacts]
# [2026-07-29 01:30:50,757: INFO: common: created directory at: artifacts/data_ingestion]
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# Cell In[24], line 8
#       6     data_ingestion.extract_zip_file()
#       7 except Exception as e:
# ----> 8     raise e
#
# Cell In[24], line 5
#       3     data_ingestion_config = config.get_data_ingestion_config()
#       4     data_ingestion = DataIngestion(config=data_ingestion_config)
# ----> 5     data_ingestion.download_file()
#       6     data_ingestion.extract_zip_file()
#       7 except Exception as e:
#
# Cell In[21], line 9, in DataIngestion.download_file(self)
#       7 def download_file(self):
#       8     if not os.path.exists(self.config.local_data_file):
# ----> 9         filename, headers = request.urlretrieve(
#      10             url = self.config.source_URL,
#      11             filename = self.config.local_data_file
#      12         )
#      13         logger.info(f"{filename} download! with following info: \n{headers}")
#      14     else:
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\urllib\request.py:239, in urlretrieve(url, filename, reporthook, data)
#     222 """
#     223 Retrieve a URL into a temporary location on disk.
#     224
#    (...)
#     235 data file as well as the resulting HTTPMessage object.
#     236 """
#     237 url_type, path = _splittype(url)
# --> 239 with contextlib.closing(urlopen(url, data)) as fp:
#     240     headers = fp.info()
#     242     # Just return the local path and the "headers" for file://
#     243     # URLs. No sense in performing a copy unless requested.
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\urllib\request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     514     req = meth(req)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#     520 meth_name = protocol+"_response"
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\urllib\request.py:534, in OpenerDirector._open(self, req, data)
#     531     return result
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#     537     return result
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\urllib\request.py:1389, in HTTPSHandler.https_open(self, req)
#    1388 def https_open(self, req):
# -> 1389     return self.do_open(http.client.HTTPSConnection, req,
#    1390         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\urllib\request.py:1315, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1312     raise URLError('no host given')
#    1314 # will parse host:port
# -> 1315 h = http_class(host, timeout=req.timeout, **http_conn_args)
#    1316 h.set_debuglevel(self._debuglevel)
#    1318 headers = dict(req.unredirected_hdrs)
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\http\client.py:1424, in HTTPSConnection.__init__(self, host, port, key_file, cert_file, timeout, source_address, context, check_hostname, blocksize)
#    1422 self.cert_file = cert_file
#    1423 if context is None:
# -> 1424     context = ssl._create_default_https_context()
#    1425     # enable PHA for TLS 1.3 connections if available
#    1426     if context.post_handshake_auth is not None:
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\ssl.py:753, in create_default_context(purpose, cafile, capath, cadata)
#     748     context.load_verify_locations(cafile, capath, cadata)
#     749 elif context.verify_mode != CERT_NONE:
#     750     # no explicit cafile, capath or cadata but the verify mode is
#     751     # CERT_OPTIONAL or CERT_REQUIRED. Let's try to load default system
#     752     # root CA certificates for the given purpose. This may fail silently.
# --> 753     context.load_default_certs(purpose)
#     754 # OpenSSL 1.1.1 keylog file
#     755 if hasattr(context, 'keylog_filename'):
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\ssl.py:577, in SSLContext.load_default_certs(self, purpose)
#     575 if sys.platform == "win32":
#     576     for storename in self._windows_cert_stores:
# --> 577         self._load_windows_store_certs(storename, purpose)
#     578 self.set_default_verify_paths()
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\ssl.py:569, in SSLContext._load_windows_store_certs(self, storename, purpose)
#     567     warnings.warn("unable to enumerate Windows certificate store")
#     568 if certs:
# --> 569     self.load_verify_locations(cadata=certs)
#     570 return certs
#
# SSLError: [ASN1: NOT_ENOUGH_DATA] not enough data (_ssl.c:4192)

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_url: str
    local_data_file: Path
    unzip_dir: Path

# %%
from cnnClassification.constants import *
from cnnClassification.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_url=config.source_url,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir 
        )

        return data_ingestion_config

# %%
import os
import urllib.request as request
# import requests
# import certifi
import zipfile
from cnnClassification import logger
from cnnClassification.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config


    def download_file(self):
        if not os.path.exists(self.config.local_data_file):
            filename, headers = request.urlretrieve(
                url = self.config.source_url,
                filename = self.config.local_data_file
            )
            logger.info(f"{filename} download! with following info: \n{headers}")
        else:
            logger.info(f"File already exists of size: {get_size(Path(self.config.local_data_file))}")


    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file into the data directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# [2026-07-29 01:10:16,583: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-07-29 01:10:16,587: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-07-29 01:10:16,589: INFO: common: created directory at: artifacts]
# [2026-07-29 01:10:16,593: INFO: common: created directory at: artifacts/data_ingestion]
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# Cell In[15], line 8
#       6     data_ingestion.extract_zip_file()
#       7 except Exception as e:
# ----> 8     raise e
#
# Cell In[15], line 5
#       3     data_ingestion_config = config.get_data_ingestion_config()
#       4     data_ingestion = DataIngestion(config=data_ingestion_config)
# ----> 5     data_ingestion.download_file()
#       6     data_ingestion.extract_zip_file()
#       7 except Exception as e:
#
# Cell In[14], line 8, in DataIngestion.download_file(self)
#       6 def download_file(self):
#       7     if not os.path.exists(self.config.local_data_file):
# ----> 8         filename, headers = request.urlretrieve(
#       9             url = self.config.source_url,
#      10             filename = self.config.local_data_file
#      11         )
#      12         logger.info(f"{filename} download! with following info: \n{headers}")
#      13     else:
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\urllib\request.py:239, in urlretrieve(url, filename, reporthook, data)
#     222 """
#     223 Retrieve a URL into a temporary location on disk.
#     224
#    (...)
#     235 data file as well as the resulting HTTPMessage object.
#     236 """
#     237 url_type, path = _splittype(url)
# --> 239 with contextlib.closing(urlopen(url, data)) as fp:
#     240     headers = fp.info()
#     242     # Just return the local path and the "headers" for file://
#     243     # URLs. No sense in performing a copy unless requested.
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\urllib\request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     514     req = meth(req)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#     520 meth_name = protocol+"_response"
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\urllib\request.py:534, in OpenerDirector._open(self, req, data)
#     531     return result
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#     537     return result
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\urllib\request.py:1389, in HTTPSHandler.https_open(self, req)
#    1388 def https_open(self, req):
# -> 1389     return self.do_open(http.client.HTTPSConnection, req,
#    1390         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\urllib\request.py:1315, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1312     raise URLError('no host given')
#    1314 # will parse host:port
# -> 1315 h = http_class(host, timeout=req.timeout, **http_conn_args)
#    1316 h.set_debuglevel(self._debuglevel)
#    1318 headers = dict(req.unredirected_hdrs)
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\http\client.py:1424, in HTTPSConnection.__init__(self, host, port, key_file, cert_file, timeout, source_address, context, check_hostname, blocksize)
#    1422 self.cert_file = cert_file
#    1423 if context is None:
# -> 1424     context = ssl._create_default_https_context()
#    1425     # enable PHA for TLS 1.3 connections if available
#    1426     if context.post_handshake_auth is not None:
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\ssl.py:753, in create_default_context(purpose, cafile, capath, cadata)
#     748     context.load_verify_locations(cafile, capath, cadata)
#     749 elif context.verify_mode != CERT_NONE:
#     750     # no explicit cafile, capath or cadata but the verify mode is
#     751     # CERT_OPTIONAL or CERT_REQUIRED. Let's try to load default system
#     752     # root CA certificates for the given purpose. This may fail silently.
# --> 753     context.load_default_certs(purpose)
#     754 # OpenSSL 1.1.1 keylog file
#     755 if hasattr(context, 'keylog_filename'):
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\ssl.py:577, in SSLContext.load_default_certs(self, purpose)
#     575 if sys.platform == "win32":
#     576     for storename in self._windows_cert_stores:
# --> 577         self._load_windows_store_certs(storename, purpose)
#     578 self.set_default_verify_paths()
#
# File c:\Users\User\.conda\envs\cnns_venv\lib\ssl.py:569, in SSLContext._load_windows_store_certs(self, storename, purpose)
#     567     warnings.warn("unable to enumerate Windows certificate store")
#     568 if certs:
# --> 569     self.load_verify_locations(cadata=certs)
#     570 return certs
#
# SSLError: [ASN1: NOT_ENOUGH_DATA] not enough data (_ssl.c:4192)
